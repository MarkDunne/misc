# %%
# %matplotlib inline

import math
import numpy as np
from scipy.io.wavfile import read
import matplotlib.pyplot as plt
from scipy.fftpack import fft

# %%
def max_power_two(n):
    return 2 ** int(math.log(n, 2))

# %%
input_data = read('/home/mark/Music/dancin.wav')
audio = input_data[1]
audio = audio[:max_power_two(len(audio))]
audio = audio / (2**15.)

# %%
300 / (120.0 * input_data[0] / len(audio))
# Out:
# 475.5446712018141

# %%
bitrate = input_data[0]

# %%
freqs = np.fft.fft(audio)
freqs = freqs[bitrate * 80 : bitrate * 200]

# %%
plt.plot(np.diff(freqs_avg[10:300]))

# %%
plt.plot(freqs)
# Out:
# /home/mark/anaconda/lib/python2.7/site-packages/numpy/core/numeric.py:462: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
np.average(np.argmax(freqs_avg[10:300]))
# Out:
# 52.0

# %%
np.argwhere(freqs_avg[10:300] > 1500)
# Out:
# array([[49],
#        [52],
#        [53],
#        [55],
#        [58]])

# %%
freqs_avg[70:90]
# Out:
# array([  556.35724595,  1251.23723041,   689.7580817 ,   393.72355387,
#         1022.38515198,   535.41465631,   355.40210757,  1026.75048666,
#          451.00467994,   321.75811179,  1037.26952292,   404.41814579,
#          298.64952648,  1062.29657213,   400.0943753 ,   373.30295841,
#         1265.75232671,   839.30995941,   346.56707242,  1261.62164966])

# %%
plt.plot(np.abs(np.fft.fft(audio)[10:300]))

# %%
np.argwhere(np.abs(np.fft.fft(audio)[10:300]) > 1500)
# Out:
# array([[180],
#        [182]])

# %%
freqs = np.abs(np.fft.fft(audio)[10:300])
np.percentile(freqs, 90)
# Out:
# 646.83673833979356

# %%
(np.argwhere(freqs > np.percentile(freqs, 99))[0] * 2)
# Out:
# array([356])

# %%
np.argwhere([freqs > np.percentile(freqs, 99)])
# Out:
# array([[  0, 178],
#        [  0, 180],
#        [  0, 182]])
