# %%
# %matplotlib inline

import Quandl
import numpy as np
import pandas as pd
import pandas.io.data as web
from datetime import datetime
import matplotlib.pyplot as plt

# %%
dataset = Quandl.get(
    ['GOOG/NASDAQ_AAPL', 'GOOG/NYSE_IBM', 'GOOG/NASDAQ_MSFT'], 
    trim_start=datetime(2000, 1, 1), 
    authtoken='pdRRzNygCjs_YY5Y2MVe')

# %%
[x for x in dataset]
# Out:
# [u'GOOG.NASDAQ_AAPL - Open',
#  u'GOOG.NASDAQ_AAPL - High',
#  u'GOOG.NASDAQ_AAPL - Low',
#  u'GOOG.NASDAQ_AAPL - Close',
#  u'GOOG.NASDAQ_AAPL - Volume',
#  u'GOOG.NYSE_IBM - Open',
#  u'GOOG.NYSE_IBM - High',
#  u'GOOG.NYSE_IBM - Low',
#  u'GOOG.NYSE_IBM - Close',
#  u'GOOG.NYSE_IBM - Volume',
#  u'GOOG.NASDAQ_MSFT - Open',
#  u'GOOG.NASDAQ_MSFT - High',
#  u'GOOG.NASDAQ_MSFT - Low',
#  u'GOOG.NASDAQ_MSFT - Close',
#  u'GOOG.NASDAQ_MSFT - Volume']

# %%
dataset = dataset[['GOOG.NASDAQ_AAPL - Close', 'GOOG.NYSE_IBM - Close', 'GOOG.NASDAQ_MSFT - Close']]
dataset.dropna(inplace=True)

# %%
np.random.randn(4, 5)
# Out:
# array([[-1.80957707,  1.37281688, -1.22801743,  1.13582697,  0.42965807],
#        [ 1.50564071,  0.84488389, -0.42013613,  0.15472549, -0.81912442],
#        [-0.17886249,  0.58288265, -2.01378828,  0.98062939, -0.80023369],
#        [ 0.47250702,  0.22882591, -1.77155435, -1.28375164,  0.6471969 ]])

# %%
dataset.plot()

# %%
def rand_weights(n):
    ''' Produces n random weights that sum to 1 '''
    k = np.random.rand(n)
    return k / sum(k)

# %%
def random_portfolio(returns):
    ''' 
    Returns the mean and standard deviation of returns for a random portfolio
    '''

    p = np.asmatrix(np.mean(returns, axis=1))
    w = np.asmatrix(rand_weights(returns.shape[0]))
    C = np.asmatrix(np.cov(returns))
    
    mu = w * p.T
    sigma = np.sqrt(w * C * w.T)
    
    # This recursion reduces outliers to keep plots pretty
    return mu, sigma

# %%
means = []
stds = []
for _ in xrange(200):
    weights = np.random.random(size=3)
    returns = np.diff((dataset * weights).sum(axis=1))
    means.append(np.mean(returns))
    stds.append(np.std(returns))

# %%
plt.scatter(means, stds)
